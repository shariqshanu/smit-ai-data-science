# %%
for a in range(1, 18):
  print(f"You are a Kid! {a}")
# Out:
# You are a Kid! 1
# You are a Kid! 2
# You are a Kid! 3
# You are a Kid! 4
# You are a Kid! 5
# You are a Kid! 6
# You are a Kid! 7
# You are a Kid! 8
# You are a Kid! 9
# You are a Kid! 10
# You are a Kid! 11
# You are a Kid! 12
# You are a Kid! 13
# You are a Kid! 14
# You are a Kid! 15
# You are a Kid! 16
# You are a Kid! 17

# %%
age = 1
while age<18:
  print(f"You are a Kid! {age}")
  age+=1
# Out:
# You are a Kid! 1
# You are a Kid! 2
# You are a Kid! 3
# You are a Kid! 4
# You are a Kid! 5
# You are a Kid! 6
# You are a Kid! 7
# You are a Kid! 8
# You are a Kid! 9
# You are a Kid! 10
# You are a Kid! 11
# You are a Kid! 12
# You are a Kid! 13
# You are a Kid! 14
# You are a Kid! 15
# You are a Kid! 16
# You are a Kid! 17

# %%
names = ["usman", 'phil', 'arham', 'amir', 'sarah', 'rehan', 'taha', 'nasir']
for n in names:
  print(f"Wellcom {n}")
# Out:
# Wellcom usman
# Wellcom phil
# Wellcom arham
# Wellcom amir
# Wellcom sarah
# Wellcom rehan
# Wellcom taha
# Wellcom nasir

# %%
names = ["usman", 'phil', 'arham', 'amir', 'sarah', 'rehan', 'taha', 'nasir']
index = 0
while index <= 7:
  print(f"Welcom {names[index]}")
  index += 1
# Out:
# Welcom usman
# Welcom phil
# Welcom arham
# Welcom amir
# Welcom sarah
# Welcom rehan
# Welcom taha
# Welcom nasir
