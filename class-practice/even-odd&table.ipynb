# %%
a = ['ALi', 'Usman', 'Haider']
for abc in a:
  print(abc)
# Out:
# ALi
# Usman
# Haider

# %%
num = int(input('Enter you number'))
for n in range(1,11):
  print(f"{num} * {n} : {num*n}")
# Out:
# Enter you number5
# 5 * 1 : 5
# 5 * 2 : 10
# 5 * 3 : 15
# 5 * 4 : 20
# 5 * 5 : 25
# 5 * 6 : 30
# 5 * 7 : 35
# 5 * 8 : 40
# 5 * 9 : 45
# 5 * 10 : 50

# %%
selectedTableNumer = int(input("Enter your number: "))
for n in range(1,11):
  print(f"{selectedTableNumer} * {n} = {selectedTableNumer*n}")
# Out:
# Enter your number: 6
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
# 6 * 10 = 60

# %%
for repeatedName in range(10):
  print('Ali')
# Out:
# Ali
# Ali
# Ali
# Ali
# Ali
# Ali
# Ali
# Ali
# Ali
# Ali

# %%
for name in ['Haider', 'Ali', 'Orhan', 'Ahmed']:
  print("Hello Hy ", name)
# Out:
# Hello Hy  Haider
# Hello Hy  Ali
# Hello Hy  Orhan
# Hello Hy  Ahmed

# %%
for number in range(20):
  if number%2 == 0:
    print("Event Number: ", number)
  else:
    print("odd Number: ", number)
# Out:
# Event Number:  0
# odd Number:  1
# Event Number:  2
# odd Number:  3
# Event Number:  4
# odd Number:  5
# Event Number:  6
# odd Number:  7
# Event Number:  8
# odd Number:  9
# Event Number:  10
# odd Number:  11
# Event Number:  12
# odd Number:  13
# Event Number:  14
# odd Number:  15
# Event Number:  16
# odd Number:  17
# Event Number:  18
# odd Number:  19

# %%
tableNumber = int(input("Enter a Number "))
for n in range(1,11):
  print(f"{tableNumber} * {n} = {tableNumber*n}")
# Out:
# Enter a Number 14
# 14 * 1 = 14
# 14 * 2 = 28
# 14 * 3 = 42
# 14 * 4 = 56
# 14 * 5 = 70
# 14 * 6 = 84
# 14 * 7 = 98
# 14 * 8 = 112
# 14 * 9 = 126
# 14 * 10 = 140
