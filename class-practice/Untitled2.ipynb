# %%
# math, eng, phy, chem, urdu, Computer

# %%
math = int(input("Enter your math numbers"))
eng = int(input("Enter your english numbers"))
phy = int(input("Enter your physic numbers"))
chem = int(input("Enter your Chemistry numbers"))
urdu = int(input("Enter your urdu numbers"))
computer = int(input("Enter your computer numbers"))

total = math + eng + phy + chem + urdu + computer
persentage = total / 600 * 100

# print(persentage);
# Out:
# Enter your math numbers10
# Enter your english numbers10
# Enter your physic numbers10
# Enter your Chemistry numbers10
# Enter your urdu numbers10
# Enter your computer numbers0
# 8.333333333333332
