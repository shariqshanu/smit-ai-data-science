# %%
cset = {1, 3, 4, 5, 6, 7}
cset
# Out:
# {1, 3, 4, 5, 6, 7}

# %%
cset
# Out:
# {1, 3, 4, 5, 6, 7}

# %%
assetset = {100, 299, 3, 4, 5, 6, 7}

# %%
cset.difference(assetset)
# Out:
# {1}

# %%
assetset.difference(cset)
# Out:
# {100, 299}

# %%
assetset.discard(2)
