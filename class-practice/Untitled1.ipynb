# %%
age = 18

# %%
age
# Out:
# 18

# %%
name = input("What is your name?")
# Out:
# What is your name?Shariq

# %%
if name == "Shariq":
  print("The person is authentic.")
# Out:
# The person is authentic.

# %%
name
# Out:
# 'Shariq'

# %%
billAmount = float(input("Kindly Enter your Bill Amount"))
if billAmount >= 20000.00 :
  discount = billAmount * 0.20
  print(f"Your discount in Rs:{discount} on the purchase of Rs:{billAmount}")
else:
  print(f"You have Purchase amount is {billAmount}, so you can't avail the Discount Offer")
# Out:
# Kindly Enter your Bill Amount50000
# Your discount in Rs:10000.0 on the purchase of Rs:50000.0

# %%
age = int(input("What is your age"))
if age >= 18:
  print("Business can be done")
elif age < 18 and age >= 12:
  print("You need to learn how to run business")
else:
  print("just do what you want")
# Out:
# What is your age10
# just do what you want

# %%
myName = "Shariq"
designation = input(f"{myName} Are you Web Developer?")
if myName == 'Ali':
  print("not Shariq")
elif myName == 'hanzala':
  print("This is also not Shariq.")
elif myName == 'Shariq':
  print("Yes, You are Shariq, now you can run the next code.")
  if designation == 'Yes'
    print('okay thanks Shariq.')
else:
  print("Please Try Again")
