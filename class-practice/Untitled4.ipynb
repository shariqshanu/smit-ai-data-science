# %%
glossary =
for k,y in glossary.item():
  print(f"""{k}:
            {y}""")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4890/3643966735.py in <cell line: 0>()
# ----> 1 for k,y in glossary.item():
#       2   print(f"""{k}:
#       3             {y}""")
#
# NameError: name 'glossary' is not defined

# %%
favorite_language = {
    'joh': 'paython',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'paython'
}

# %%
for name in sorted(favorite_language.keys()):
  print(name.title(), "thank you for taking the poll")
# Out:
# Edward thank you for taking the poll
# Joh thank you for taking the poll
# Phil thank you for taking the poll
# Sarah thank you for taking the poll

# %%
print("The following language have been mentioned:")
for language in favorite_language.values():
  print(f"- {language.title()}");
# Out:
# The following language have been mentioned:
# - Paython
# - C
# - Ruby
# - Paython

# %%
people = ['Usman', 'phil', 'arham', 'amir', 'sarah', r'rehan', 'taha', 'nasir']
for banda in people:
  if banda in favorite_language.keys():
    print(f"{banda}, thank you for your response!")
  else:
    print(f"{banda}, you are invited the take the poll")
# Out:
# Usman, you are invited the take the poll
# phil, thank you for your response!
# arham, you are invited the take the poll
# amir, you are invited the take the poll
# sarah, thank you for your response!
# rehan, you are invited the take the poll
# taha, you are invited the take the poll
# nasir, you are invited the take the poll

# %%
pizza = {
    'crust': 'thick',
    'toppings': ['mashrooms', 'extra cheese'],
}

# %%
students = {
    'rolls': [1, 2, 3, 4, 5, 6, 7, 8, 9],
    'name': ['usaman', 'phil', 'arham', 'amir', 'sarah', 'rehan', 'taha', 'nasir'],
    'course': ['paython', 'web', 'graphics', 'paython', 'payhton', 'web', 'web', 'graphics']
}

# %%
print(students)
# Out:
# {'rolls': [1, 2, 3, 4, 5, 6, 7, 8, 9], 'name': ['usaman', 'phil', 'arham', 'amir', 'sarah', 'rehan', 'taha', 'nasir'], 'course': ['paython', 'web', 'graphics', 'paython', 'payhton', 'web', 'web', 'graphics']}

# %%
print(students['course'])
# Out:
# ['paython', 'web', 'graphics', 'paython', 'payhton', 'web', 'web', 'graphics']

# %%
# store information about a pizza being ordered
pizza = {
    'crust': 'thick',
    'toppings': ['mushrooms', 'entra chesse', 'peproni', 'olives', 'cheese', 'tomato']
}

# %%
# Summerize the order
print(f"your ordered a {pizza['crust']} - crust pizza, with the following topings: {pizza['toppings']}")
# Out:
# your ordered a thick - crust pizza, with the following topings: ['mushrooms', 'entra chesse', 'peproni', 'olives', 'cheese', 'tomato']

# %%
favorite_language = {
    'joh': 'paython',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'paython'
}

# %%
# Out:
# Edward thank you for taking the poll
# Joh thank you for taking the poll
# Phil thank you for taking the poll
# Sarah thank you for taking the poll
